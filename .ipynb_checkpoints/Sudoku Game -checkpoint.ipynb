# %% [markdown]
# # Backend (Game logic)

# %%
import numpy as np
import copy
import time

def print_board(board):
    for row in board:
        print(" ".join(map(str, row)))

def is_valid_move(board, row, col, num):
    # Check if the number is not present in the same row
    if num in board[row]:
        return False
    
    # Check if the number is not present in the same column
    if num in [board[i][col] for i in range(9)]:
        return False
    
    # Check if the number is not present in the 3x3 subgrid
    subgrid_row, subgrid_col = 3 * (row // 3), 3 * (col // 3)
    for i in range(subgrid_row, subgrid_row + 3):
        for j in range(subgrid_col, subgrid_col + 3):
            if board[i][j] == num:
                return False
    
    return True


def is_empty_cell(board):
    min_remaining_values = float('inf')
    selected_cell = None
    for i in range(9):
        for j in range(9):
            if board[i][j] == 0:
                remaining_values = len(get_domain_values(board, i, j))
                if remaining_values < min_remaining_values:
                    min_remaining_values = remaining_values
                    selected_cell = (i, j)
    return selected_cell


def backtracking(board):
    empty_cell = is_empty_cell(board)
    print(f"MRV is {empty_cell}")
    if empty_cell is None:
        return True

    row, col = empty_cell
    domain_values = get_domain_values(board, row, col)
    domain_values.sort(key=lambda num: count_constrained_values(board, row, col, num))

    print(f"Attempting to fill cell ({row}, {col}) with domain values: {domain_values}")

    for num in domain_values:
        print(f"Trying value {num} for cell ({row}, {col})")
        if is_valid_move(board, row, col, num):
            board[row][col] = num
            print("Applying forward checking")
            if apply_arc_consistency(board) is not None:
                print("Forward checking successful")
                if backtracking(board):
                    return True

            print(f"Value {num} for cell ({row}, {col}) leads to conflict. Backtracking...")
            board[row][col] = 0
        else:
            print(f"Value {num} is not valid for cell ({row}, {col}). Skipping...")

    print(f"No valid value found for cell ({row}, {col}). Backtracking...")
    return False


def get_domain_values(board, row, col):
    domain_values = [num for num in range(1, 10) if is_valid_move(board, row, col, num)]
    return domain_values

def count_constrained_values(board, row, col, num):
    count = 0
    for i in range(9):
        if i != col and not is_valid_move(board, row, i, num):
            count += 1
        if i != row and not is_valid_move(board, i, col, num):
            count += 1
    for i in range(row - row % 3, row - row % 3 + 3):
        for j in range(col - col % 3, col - col % 3 + 3):
            if (i != row or j != col) and not is_valid_move(board, i, j, num):
                count += 1
    return count

def forward_checking(board, row, col, num):
    original_board = copy.deepcopy(board)  # Make a copy of the board before making changes

    # Make the assignment
    board[row][col] = num

    # Check consistency with peers
    for i in range(9):
        if i != col and board[row][i] == num:  # Check for conflicts in the same row
            board[row][col] = 0  # Revert the assignment
            return False
        if i != row and board[i][col] == num:  # Check for conflicts in the same column
            board[row][col] = 0  # Revert the assignment
            return False
    for i in range(row - row % 3, row - row % 3 + 3):
        for j in range(col - col % 3, col - col % 3 + 3):
            if (i != row or j != col) and board[i][j] == num:  # Check for conflicts in the same 3x3 subgrid
                board[row][col] = 0  # Revert the assignment
                return False

    return True  # No conflicts found

def apply_arc_consistency(board):
    queue = []
    domains = [[list(range(1, 10)) for _ in range(9)] for _ in range(9)]
    steps = []  # List to store the steps of arc consistency

    for i in range(9):
        for j in range(9):
            if board[i][j] != 0:
                domains[i][j] = [board[i][j]]
                queue.append((i, j))

    def revise(xi, xj):
        revised = False
        removed_values = []
        for value in domains[xi[0]][xi[1]]:
            if isinstance(domains[xj[0]][xj[1]], list) and value in domains[xj[0]][xj[1]]:
                domains[xi[0]][xi[1]].remove(value)
                removed_values.append(value)
                revised = True
        if revised:
            steps.append(((xi[0], xi[1]), (xj[0], xj[1]), removed_values))
            print(f"Revised: {removed_values} removed from ({xi[0]}, {xi[1]})'s domain due to ({xj[0]}, {xj[1]})")
        return revised

    while queue:
        xi, xj = queue.pop(0)
        print(f"Processing cell ({xi}, {xj})")
        for i in range(9):
            if i != xi and revise((i, xj), (xi, xj)):
                if len(domains[i][xj]) == 0:
                    return None, steps
                queue.append((i, xj))
        for j in range(9):
            if j != xj and revise((xi, j), (xi, xj)):
                if len(domains[xi][j]) == 0:
                    return None, steps
                queue.append((xi, j))

    return domains, steps


def solve_sudoku(initial_board):
    board = copy.deepcopy(initial_board)

    if not backtracking(board):
        print("The puzzle is unsolvable.")
        return None

    domains, steps = apply_arc_consistency(board)
    if domains is None:
        print("Arc consistency failed. The puzzle might be unsolvable.")
        return None

    # Create a new board with resolved values
    solved_board = [[domains[i][j][0] if isinstance(domains[i][j], list) and len(domains[i][j]) == 1 else 0 for j in range(9)] for i in range(9)]

    return solved_board

def is_valid_sudoku(board):
    def is_valid_row(board, row):
        seen = set()
        for num in board[row]:
            if num != 0:
                if num in seen:
                    return False
                seen.add(num)
        return True

    def is_valid_column(board, col):
        seen = set()
        for row in range(9):
            num = board[row][col]
            if num != 0:
                if num in seen:
                    return False
                seen.add(num)
        return True

    def is_valid_subgrid(board, start_row, start_col):
        seen = set()
        for row in range(start_row, start_row + 3):
            for col in range(start_col, start_col + 3):
                num = board[row][col]
                if num != 0:
                    if num in seen:
                        return False
                    seen.add(num)
        return True

    for i in range(9):
        if not is_valid_row(board, i) or not is_valid_column(board, i):
            return False

    for i in range(0, 9, 3):
        for j in range(0, 9, 3):
            if not is_valid_subgrid(board, i, j):
                return False

    return True


def is_initial_state_valid(board):
    if not is_valid_sudoku(board):
        print("The initial state of the Sudoku puzzle is not valid.")
        return False

    return True

def generate_random_puzzle():
    # Create an empty Sudoku board
    board = np.zeros((9, 9), dtype=int)

    # Fill random places of the puzzle
    for _ in range(np.random.randint(12, 25)):  # Adjust the range for puzzle difficulty
        row, col, num = np.random.randint(9, size=3)
        while not is_valid_move(board, row, col, num + 1):
            row, col, num = np.random.randint(9, size=3)
        board[row][col] = num + 1

    return board

# %% [markdown]
# # Frontend (GUI)

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Constants
WIDTH, HEIGHT = 1050, 742
BUTTON_WIDTH, BUTTON_HEIGHT = 350, 100
BUTTON_GAP = 100

# Colors
WHITE = (255, 255, 255)
LIGHTGREY = (170, 170, 170)
GRAY = (233, 228, 216)
DARKGREY = (36, 18, 63)
DARKER_GREY = (35, 35, 35)
PURPLE = (125, 84, 222)
BLACK = (0, 0, 0)
RED = (230, 30, 30)
DARKRED = (150, 0, 0)
GREEN = (30, 230, 30)
DARKGREEN = (0, 125, 0)
BLUE = (30, 30, 122)
CYAN = (30, 230, 230)
GOLD = (225, 185, 0)
DARKGOLD = (165, 125, 0)
YELLOW = (255, 255, 0)
PERIWINKLE = (183, 195, 243)

# Create the main window
window = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Sudoku Game By Saad & Morougue")

# Load background image
background_image = pygame.image.load("background_image.png")
background_image = pygame.transform.scale(background_image, (WIDTH, HEIGHT))

# Fonts
font = pygame.font.SysFont(None, 36)

# Buttons
button_font = pygame.font.SysFont(None, 24)

buttons = [
    pygame.Rect((WIDTH - BUTTON_WIDTH) // 2, 100, BUTTON_WIDTH, BUTTON_HEIGHT),
    pygame.Rect((WIDTH - BUTTON_WIDTH) // 2, 300, BUTTON_WIDTH, BUTTON_HEIGHT),
    pygame.Rect((WIDTH - BUTTON_WIDTH) // 2, 500, BUTTON_WIDTH, BUTTON_HEIGHT)
]

button_texts = [
    "Mode 1: AI Generate And Solve",
    "Mode 2: User Generate And AI Solve",
    "Mode 3: User Generate And User Solve"
]
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def draw_sudoku_board(window, board):
    cell_size = 70
    cell_margin = 10
    board_size = 9 * cell_size + 10 * cell_margin
    board_start_x = 15
    board_start_y = 15

    # Define a larger font size for the numbers
    number_font = pygame.font.SysFont(None, 40)

    for i in range(9):
        for j in range(9):
            cell_x = board_start_x + j * (cell_size + cell_margin)
            cell_y = board_start_y + i * (cell_size + cell_margin)
            pygame.draw.rect(window, WHITE, (cell_x, cell_y, cell_size, cell_size), border_radius=10)
            
            if board[i][j] != 0:
                # Render the number with the larger font size
                text_surface = number_font.render(str(board[i][j]), True, PURPLE)
                text_rect = text_surface.get_rect(center=(cell_x + cell_size / 2, cell_y + cell_size / 2))
                window.blit(text_surface, text_rect)

# %%
def mode_1_window():
    # Create a new window for Mode 1
    mode_1_window = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Sudoku Mode 1")
    unsolvable_sound = pygame.mixer.Sound('1.wav')  # Replace 'unsolvable_sound.wav' with your sound file


    # Generate a random Sudoku puzzle
    puzzle = generate_random_puzzle()

    # Main loop for Mode 1 window
    mode_1_running = True
    error_message = None  # Initialize error message to None
    while mode_1_running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                mode_1_running = False
                pygame.quit()
                sys.exit()
            elif event.type == pygame.MOUSEBUTTONDOWN:
                # Check if solve button is clicked
                if 790 <= event.pos[0] <= 990 and 600 <= event.pos[1] <= 650:
                    # Solve the puzzle
                    st = time.time()
                    solved_puzzle = solve_sudoku(puzzle)
                    ed = time.time()
                    if solved_puzzle is not None:
                        # Calculate and print the elapsed time
                        elapsed_time = ed - st
                        print(f"The code took {elapsed_time:.5f} seconds to execute.")
                        # Update the Sudoku board if the puzzle is solvable
                        puzzle = solved_puzzle
                        error_message = None  # Clear any previous error message
                    else:
                        # Set error message if the puzzle is unsolvable
                        error_message = "The puzzle is unsolvable."
                        unsolvable_sound.play()

                # Check if regenerate button is clicked
                elif 790 <= event.pos[0] <= 990 and 675 <= event.pos[1] <= 725:
                    # Regenerate the puzzle
                    puzzle = generate_random_puzzle()
                    error_message = None  # Clear any previous error message
                # Check if back button is clicked
                elif 950 <= event.pos[0] <= 1000 and 10 <= event.pos[1] <= 30:
                    # Exit Mode 1 and return to main window
                    mode_1_running = False

        # Draw the Sudoku board
        mode_1_window.fill(DARKGREY)
        draw_sudoku_board(mode_1_window, puzzle)

        # Draw error message if present
        if error_message:
            error_font = pygame.font.SysFont(None, 36)
            error_text = error_font.render(error_message, True, RED)
            error_rect = error_text.get_rect(center=(WIDTH // 2, HEIGHT // 2))
            mode_1_window.blit(error_text, error_rect)

        # Draw buttons
        pygame.draw.rect(mode_1_window, PURPLE, (790, 600 - 5, 200, 50), border_radius=5)
        pygame.draw.rect(mode_1_window, PURPLE, (790, 675 - 5, 200, 50), border_radius=5)
        pygame.draw.rect(mode_1_window, PERIWINKLE, (950, 10, 50, 20), border_radius=5)  # Back button

        # Add text to buttons
        button_font = pygame.font.SysFont(None, 24)
        regenerate_text = button_font.render("Solve Board", True, WHITE)
        solve_text = button_font.render("Regenerate New", True, WHITE)
        mode_1_window.blit(regenerate_text, (835, 610))
        mode_1_window.blit(solve_text, (830, 685))
        back_text = button_font.render("Back", True, DARKGREY)
        mode_1_window.blit(back_text, (955, 12))

        # Update the display
        pygame.display.flip()

# %%
def mode_2_window():
    # Create a new window for Mode 2
    mode_2_window = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Sudoku Mode 2")
    unsolvable_sound = pygame.mixer.Sound('1.wav')  # Replace 'unsolvable_sound.wav' with your sound file


    # Initialize an empty Sudoku puzzle
    puzzle = [[0 for _ in range(9)] for _ in range(9)]

    # Track the selected cell position
    selected_cell = None

    # Main loop for Mode 2 window
    mode_2_running = True
    error_message = None  # Initialize error message to None
    while mode_2_running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                mode_2_running = False
                pygame.quit()
                sys.exit()
            elif event.type == pygame.MOUSEBUTTONDOWN:
                # Check if back button is clicked
                if 950 <= event.pos[0] <= 1000 and 10 <= event.pos[1] <= 30:
                    # Exit Mode 2 and return to the main window
                    mode_2_running = False
                elif 790 <= event.pos[0] <= 990 and 670 <= event.pos[1] <= 720:
                    # Check if the puzzle is valid
                    if is_valid_sudoku(puzzle):
                        # Solve the puzzle when "Solve Board" button is clicked
                        st = time.time()
                        solved_puzzle = solve_sudoku(puzzle)
                        ed = time.time()
                        if solved_puzzle is not None:
                            # Calculate and print the elapsed time
                            elapsed_time = ed - st
                            print(f"The code took {elapsed_time:.5f} seconds to execute.")
                            puzzle = solved_puzzle
                            error_message = None  # Clear any previous error message
                        else:
                            error_message = "The puzzle is unsolvable."
                            unsolvable_sound.play()

                    else:
                        error_message = "Invalid Sudoku Input, Please Check Game Constrains"
                elif 790 <= event.pos[0] <= 990 and 600 <= event.pos[1] <= 650:
                    # Reset the puzzle when "Reset Board" button is clicked
                    puzzle = [[0 for _ in range(9)] for _ in range(9)]
                    error_message = None  # Clear any previous error message
                else:
                    # Get the clicked cell position
                    cell_x = (event.pos[0] - 10) // 80  # Calculate cell column based on click position
                    cell_y = (event.pos[1] - 10) // 80  # Calculate cell row based on click position
                    if 0 <= cell_x < 9 and 0 <= cell_y < 9:
                        # Highlight the selected cell
                        selected_cell = (cell_x, cell_y)

            elif event.type == pygame.KEYDOWN and selected_cell is not None:
                # Check if a number key (1-9) is pressed
                if pygame.K_1 <= event.key <= pygame.K_9:
                    # Update the value of the selected cell
                    puzzle[selected_cell[1]][selected_cell[0]] = int(event.unicode)
                elif event.key == pygame.K_DELETE or event.key == pygame.K_BACKSPACE:
                    # Clear the value of the selected cell
                    puzzle[selected_cell[1]][selected_cell[0]] = 0

        # Draw the Sudoku board
        mode_2_window.fill(DARKGREY)
        draw_sudoku_board(mode_2_window, puzzle)

        # Draw yellow highlight for the selected cell
        if selected_cell is not None:
            cell_x, cell_y = selected_cell
            pygame.draw.rect(mode_2_window, YELLOW, (cell_x * 80 + 12, cell_y * 80 + 12, 73, 73), 5, border_radius=10)

        # Draw error message if present
        if error_message:
            error_font = pygame.font.SysFont(None, 36)
            error_text = error_font.render(error_message, True, RED)
            error_rect = error_text.get_rect(center=(WIDTH // 2, HEIGHT // 2))
            mode_2_window.blit(error_text, error_rect)

        # Draw buttons
        pygame.draw.rect(mode_2_window, PURPLE, (790, 670, 200, 50), border_radius=5)
        pygame.draw.rect(mode_2_window, PURPLE, (790, 600, 200, 50), border_radius=5)
        pygame.draw.rect(mode_2_window, PERIWINKLE, (950, 10, 50, 20), border_radius=5)  # Back button

        # Add text to buttons
        button_font = pygame.font.SysFont(None, 24)
        solve_text = button_font.render("Solve Board", True, WHITE)
        mode_2_window.blit(solve_text, (840, 685))
        reset_text = button_font.render("Reset Board", True, WHITE)
        mode_2_window.blit(reset_text, (840, 615))
        back_text = button_font.render("Back", True, DARKGREY)
        mode_2_window.blit(back_text, (955, 12))

        # Update the display
        pygame.display.flip()

    # Once the user exits the Mode 2 window, return the user input Sudoku puzzle
    return puzzle

# %%
def mode_3_window():
    # Create a new window for Mode 2
    mode_2_window = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Sudoku Mode 3")
    unsolvable_sound = pygame.mixer.Sound('1.wav')  # Replace 'unsolvable_sound.wav' with your sound file


    # Initialize an empty Sudoku puzzle
    puzzle = [[0 for _ in range(9)] for _ in range(9)]

    # Track the selected cell position
    selected_cell = None

    # Initialize solved puzzle and user input grid
    solved_puzzle = None
    user_input_grid = [[0 for _ in range(9)] for _ in range(9)]

    # Main loop for Mode 2 window
    mode_2_running = True
    error_message = None  # Initialize error message to None
    while mode_2_running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                mode_2_running = False
                pygame.quit()
                sys.exit()
            elif event.type == pygame.MOUSEBUTTONDOWN:
                # Check if back button is clicked
                if 950 <= event.pos[0] <= 1000 and 10 <= event.pos[1] <= 30:
                    # Exit Mode 2 and return to the main window
                    mode_2_running = False
                elif 790 <= event.pos[0] <= 990 and 670 <= event.pos[1] <= 720:
                    # Solve the puzzle and store the solution
                    if solved_puzzle is None:
                        solved_puzzle = solve_sudoku(user_input_grid)
                        print(solved_puzzle)
                elif 790 <= event.pos[0] <= 990 and 600 <= event.pos[1] <= 650:
                    # Reset the puzzle when "Reset Board" button is clicked
                    puzzle = [[0 for _ in range(9)] for _ in range(9)]
                    user_input_grid = [[0 for _ in range(9)] for _ in range(9)]
                    error_message = None  # Clear any previous error message
                else:
                    # Get the clicked cell position
                    cell_x = (event.pos[0] - 10) // 80  # Calculate cell column based on click position
                    cell_y = (event.pos[1] - 10) // 80  # Calculate cell row based on click position
                    if 0 <= cell_x < 9 and 0 <= cell_y < 9:
                        # Highlight the selected cell
                        selected_cell = (cell_x, cell_y)

            elif event.type == pygame.KEYDOWN and selected_cell is not None:
                # Check if a number key (1-9) is pressed
                if pygame.K_1 <= event.key <= pygame.K_9:
                    # Update the value of the selected cell in user input grid
                    user_input_grid[selected_cell[1]][selected_cell[0]] = int(event.unicode)
                elif event.key == pygame.K_DELETE or event.key == pygame.K_BACKSPACE:
                    # Clear the value of the selected cell in user input grid
                    user_input_grid[selected_cell[1]][selected_cell[0]] = 0

        # Draw the Sudoku board with user input
        mode_2_window.fill(DARKGREY)
        draw_sudoku_board(mode_2_window, user_input_grid)

        # Draw yellow highlight for the selected cell
        if selected_cell is not None:
            cell_x, cell_y = selected_cell
            pygame.draw.rect(mode_2_window, YELLOW, (cell_x * 80 + 12, cell_y * 80 + 12, 72, 72), 5, border_radius=10)

        # Compare user input with solver's solution in real-time
        if solved_puzzle is not None:
            for y in range(9):
                for x in range(9):
                    if user_input_grid[y][x] != 0 and user_input_grid[y][x] != solved_puzzle[y][x]:
                        # Draw red border for incorrect user input
                        pygame.draw.rect(mode_2_window, RED, (x * 80 + 12, y * 80 + 12, 72, 72), 5, border_radius=10)
                        unsolvable_sound.play()


        # Draw buttons
        pygame.draw.rect(mode_2_window, PURPLE, (790, 670, 200, 50), border_radius=5)
        pygame.draw.rect(mode_2_window, PURPLE, (790, 600, 200, 50), border_radius=5)
        pygame.draw.rect(mode_2_window, PERIWINKLE, (950, 10, 50, 20), border_radius=5)  # Back button

        # Add text to buttons
        button_font = pygame.font.SysFont(None, 24)
        solve_text = button_font.render("Solve Board", True, WHITE)
        mode_2_window.blit(solve_text, (840, 685))
        reset_text = button_font.render("Reset Board", True, WHITE)
        mode_2_window.blit(reset_text, (840, 615))
        back_text = button_font.render("Back", True, DARKGREY)
        mode_2_window.blit(back_text, (955, 12))

        # Update the display
        pygame.display.flip()

    # Once the user exits the Mode 2 window, return the user input Sudoku puzzle
    return user_input_grid

# %%
# Main loop
mode_1_active = False  # Flag to track if Mode 1 window is active
mode_2_active = False  # Flag to track if Mode 2 window is active
mode_3_active = False  # Flag to track if Mode 3 window is active
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            pygame.quit()
            sys.exit()
        elif event.type == pygame.MOUSEBUTTONDOWN:
            # Check if any button was clicked
            for i, button in enumerate(buttons):
                if button.collidepoint(event.pos):
                    if i == 0:  # Mode 1 button clicked
                        mode_1_active = True
                        mode_2_active = False
                        mode_3_active = False
                    elif i == 1:  # Mode 2 button clicked
                        mode_2_active = True
                        mode_1_active = False
                        mode_3_active = False
                    elif i == 2:  # Mode 3 button clicked
                        mode_3_active = True
                        mode_1_active = False
                        mode_2_active = False

    # Draw background and buttons
    window.blit(background_image, (0, 0))
    for i, button in enumerate(buttons):
        pygame.draw.rect(window, GRAY, button, border_radius=10)
        text = button_font.render(button_texts[i], True, BLACK)
        text_rect = text.get_rect(center=button.center)
        window.blit(text, text_rect)

    # Update the display
    pygame.display.flip()

    # If Mode 1 window is active, switch to Mode 1 window
    if mode_1_active:
        mode_1_active = False  # Reset the flag
        mode_1_window()  # Call the Mode 1 window function

    # If Mode 2 window is active, switch to Mode 2 window
    if mode_2_active:
        mode_2_active = False  # Reset the flag
        mode_2_window()  # Call the Mode 2 window function

    # If Mode 3 window is active, switch to Mode 3 window
    if mode_3_active:
        mode_3_active = False  # Reset the flag
        mode_3_window()  # Call the Mode 3 window function
# Out:
# MRV is (6, 1)
# Attempting to fill cell (6, 1) with domain values: [5, 4, 7]
# Trying value 5 for cell (6, 1)
# Applying forward checking
# Processing cell (0, 4)
# Revised: [7] removed from (1, 4)'s domain due to (0, 4)
# Revised: [7] removed from (2, 4)'s domain due to (0, 4)
# Revised: [7] removed from (3, 4)'s domain due to (0, 4)
# Revised: [7] removed from (5, 4)'s domain due to (0, 4)
# Revised: [7] removed from (7, 4)'s domain due to (0, 4)
# Revised: [7] removed from (0, 0)'s domain due to (0, 4)
# Revised: [7] removed from (0, 1)'s domain due to (0, 4)
# Revised: [7] removed from (0, 2)'s domain due to (0, 4)
# Revised: [7] removed from (0, 3)'s domain due to (0, 4)
# Revised: [7] removed from (0, 5)'s domain due to (0, 4)
# Revised: [7] removed from (0, 6)'s domain due to (0, 4)
# Revised: [7] removed from (0, 7)'s domain due to (0, 4)
# Revised: [7] removed from (0, 8)'s domain due to (0, 4)
# Processing cell (1, 1)
# Revised: [1] removed from (0, 1)'s domain due to (1, 1)
# Revised: [1] removed from (3, 1)'s domain due to (1, 1)
# Revised: [1] removed from (4, 1)'s domain due to (1, 1)
# Revised: [1] removed from (5, 1)'s domain due to (1, 1)
# Revised: [1] removed from (7, 1)'s domain due to (1, 1)
# Revised: [1] removed from (1, 0)'s domain due to (1, 1)
# Revised: [1] removed from (1, 2)'s domain due to (1, 1)
# Revised: [1] removed from (1, 3)'s domain due to (1, 1)
# Revised: [1] removed from (1, 4)'s domain due to (1, 1)
# Revised: [1] removed from (1, 5)'s domain due to (1, 1)
# Revised: [1] removed from (1, 6)'s domain due to (1, 1)
# Revised: [1] removed from (1, 7)'s domain due to (1, 1)
# Revised: [1] removed from (1, 8)'s domain due to (1, 1)
# Processing cell (2, 1)
# Revised: [3] removed from (0, 1)'s domain due to (2, 1)
# Revised: [3] removed from (3, 1)'s domain due to (2, 1)
# Revised: [3] removed from (4, 1)'s domain due to (2, 1)
# Revised: [3] removed from (5, 1)'s domain due to (2, 1)
# Revised: [3] removed from (7, 1)'s domain due to (2, 1)
# Revised: [3] removed from (2, 0)'s domain due to (2, 1)
# Revised: [3] removed from (2, 2)'s domain due to (2, 1)
# Revised: [3] removed from (2, 3)'s domain due to (2, 1)
# Revised: [3] removed from (2, 4)'s domain due to (2, 1)
# Revised: [3] removed from (2, 5)'s domain due to (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# Revised: [3] removed from (2, 7)'s domain due to (2, 1)
# Revised: [3] removed from (2, 8)'s domain due to (2, 1)
# Processing cell (3, 6)
# Revised: [1] removed from (0, 6)'s domain due to (3, 6)
# Revised: [1] removed from (2, 6)'s domain due to (3, 6)
# Revised: [1] removed from (4, 6)'s domain due to (3, 6)
# Revised: [1] removed from (5, 6)'s domain due to (3, 6)
# Revised: [1] removed from (6, 6)'s domain due to (3, 6)
# Revised: [1] removed from (8, 6)'s domain due to (3, 6)
# Revised: [1] removed from (3, 0)'s domain due to (3, 6)
# Revised: [1] removed from (3, 2)'s domain due to (3, 6)
# Revised: [1] removed from (3, 3)'s domain due to (3, 6)
# Revised: [1] removed from (3, 4)'s domain due to (3, 6)
# Revised: [1] removed from (3, 5)'s domain due to (3, 6)
# Revised: [1] removed from (3, 7)'s domain due to (3, 6)
# Revised: [1] removed from (3, 8)'s domain due to (3, 6)
# Processing cell (4, 3)
# Revised: [4] removed from (0, 3)'s domain due to (4, 3)
# Revised: [4] removed from (1, 3)'s domain due to (4, 3)
# Revised: [4] removed from (2, 3)'s domain due to (4, 3)
# Revised: [4] removed from (3, 3)'s domain due to (4, 3)
# Revised: [4] removed from (5, 3)'s domain due to (4, 3)
# Revised: [4] removed from (7, 3)'s domain due to (4, 3)
# Revised: [4] removed from (8, 3)'s domain due to (4, 3)
# Revised: [4] removed from (4, 0)'s domain due to (4, 3)
# Revised: [4] removed from (4, 1)'s domain due to (4, 3)
# Revised: [4] removed from (4, 2)'s domain due to (4, 3)
# Revised: [4] removed from (4, 5)'s domain due to (4, 3)
# Revised: [4] removed from (4, 6)'s domain due to (4, 3)
# Revised: [4] removed from (4, 7)'s domain due to (4, 3)
# Revised: [4] removed from (4, 8)'s domain due to (4, 3)
# Processing cell (4, 4)
# Revised: [1] removed from (2, 4)'s domain due to (4, 4)
# Revised: [1] removed from (5, 4)'s domain due to (4, 4)
# Revised: [1] removed from (7, 4)'s domain due to (4, 4)
# Revised: [1] removed from (4, 0)'s domain due to (4, 4)
# Revised: [1] removed from (4, 2)'s domain due to (4, 4)
# Revised: [1] removed from (4, 5)'s domain due to (4, 4)
# Revised: [1] removed from (4, 7)'s domain due to (4, 4)
# Revised: [1] removed from (4, 8)'s domain due to (4, 4)
# Processing cell (6, 1)
# Revised: [5] removed from (0, 1)'s domain due to (6, 1)
# Revised: [5] removed from (3, 1)'s domain due to (6, 1)
# Revised: [5] removed from (4, 1)'s domain due to (6, 1)
# Revised: [5] removed from (5, 1)'s domain due to (6, 1)
# Revised: [5] removed from (7, 1)'s domain due to (6, 1)
# Revised: [5] removed from (6, 0)'s domain due to (6, 1)
# Revised: [5] removed from (6, 2)'s domain due to (6, 1)
# Revised: [5] removed from (6, 5)'s domain due to (6, 1)
# Revised: [5] removed from (6, 6)'s domain due to (6, 1)
# Revised: [5] removed from (6, 8)'s domain due to (6, 1)
# Processing cell (6, 3)
# Revised: [9] removed from (0, 3)'s domain due to (6, 3)
# Revised: [9] removed from (1, 3)'s domain due to (6, 3)
# Revised: [9] removed from (2, 3)'s domain due to (6, 3)
# Revised: [9] removed from (3, 3)'s domain due to (6, 3)
# Revised: [9] removed from (5, 3)'s domain due to (6, 3)
# Revised: [9] removed from (7, 3)'s domain due to (6, 3)
# Revised: [9] removed from (8, 3)'s domain due to (6, 3)
# Revised: [9] removed from (6, 0)'s domain due to (6, 3)
# Revised: [9] removed from (6, 2)'s domain due to (6, 3)
# Revised: [9] removed from (6, 5)'s domain due to (6, 3)
# Revised: [9] removed from (6, 6)'s domain due to (6, 3)
# Revised: [9] removed from (6, 8)'s domain due to (6, 3)
# Processing cell (6, 4)
# Revised: [8] removed from (1, 4)'s domain due to (6, 4)
# Revised: [8] removed from (2, 4)'s domain due to (6, 4)
# Revised: [8] removed from (3, 4)'s domain due to (6, 4)
# Revised: [8] removed from (5, 4)'s domain due to (6, 4)
# Revised: [8] removed from (7, 4)'s domain due to (6, 4)
# Revised: [8] removed from (6, 0)'s domain due to (6, 4)
# Revised: [8] removed from (6, 2)'s domain due to (6, 4)
# Revised: [8] removed from (6, 5)'s domain due to (6, 4)
# Revised: [8] removed from (6, 6)'s domain due to (6, 4)
# Revised: [8] removed from (6, 8)'s domain due to (6, 4)
# Processing cell (6, 7)
# Revised: [2] removed from (0, 7)'s domain due to (6, 7)
# Revised: [2] removed from (1, 7)'s domain due to (6, 7)
# Revised: [2] removed from (2, 7)'s domain due to (6, 7)
# Revised: [2] removed from (3, 7)'s domain due to (6, 7)
# Revised: [2] removed from (4, 7)'s domain due to (6, 7)
# Revised: [2] removed from (5, 7)'s domain due to (6, 7)
# Revised: [2] removed from (8, 7)'s domain due to (6, 7)
# Revised: [2] removed from (6, 0)'s domain due to (6, 7)
# Revised: [2] removed from (6, 2)'s domain due to (6, 7)
# Revised: [2] removed from (6, 5)'s domain due to (6, 7)
# Revised: [2] removed from (6, 6)'s domain due to (6, 7)
# Revised: [2] removed from (6, 8)'s domain due to (6, 7)
# Processing cell (7, 6)
# Revised: [7] removed from (1, 6)'s domain due to (7, 6)
# Revised: [7] removed from (2, 6)'s domain due to (7, 6)
# Revised: [7] removed from (4, 6)'s domain due to (7, 6)
# Revised: [7] removed from (5, 6)'s domain due to (7, 6)
# Revised: [7] removed from (6, 6)'s domain due to (7, 6)
# Revised: [7] removed from (8, 6)'s domain due to (7, 6)
# Revised: [7] removed from (7, 0)'s domain due to (7, 6)
# Revised: [7] removed from (7, 1)'s domain due to (7, 6)
# Revised: [7] removed from (7, 2)'s domain due to (7, 6)
# Revised: [7] removed from (7, 3)'s domain due to (7, 6)
# Revised: [7] removed from (7, 5)'s domain due to (7, 6)
# Revised: [7] removed from (7, 8)'s domain due to (7, 6)
# Processing cell (7, 7)
# Revised: [3] removed from (0, 7)'s domain due to (7, 7)
# Revised: [3] removed from (1, 7)'s domain due to (7, 7)
# Revised: [3] removed from (3, 7)'s domain due to (7, 7)
# Revised: [3] removed from (4, 7)'s domain due to (7, 7)
# Revised: [3] removed from (5, 7)'s domain due to (7, 7)
# Revised: [3] removed from (8, 7)'s domain due to (7, 7)
# Revised: [3] removed from (7, 0)'s domain due to (7, 7)
# Revised: [3] removed from (7, 2)'s domain due to (7, 7)
# Revised: [3] removed from (7, 3)'s domain due to (7, 7)
# Revised: [3] removed from (7, 4)'s domain due to (7, 7)
# Revised: [3] removed from (7, 5)'s domain due to (7, 7)
# Revised: [3] removed from (7, 8)'s domain due to (7, 7)
# Processing cell (8, 1)
# Revised: [6] removed from (0, 1)'s domain due to (8, 1)
# Revised: [6] removed from (3, 1)'s domain due to (8, 1)
# Revised: [6] removed from (4, 1)'s domain due to (8, 1)
# Revised: [6] removed from (5, 1)'s domain due to (8, 1)
# Revised: [6] removed from (7, 1)'s domain due to (8, 1)
# Revised: [6] removed from (8, 0)'s domain due to (8, 1)
# Revised: [6] removed from (8, 2)'s domain due to (8, 1)
# Revised: [6] removed from (8, 3)'s domain due to (8, 1)
# Revised: [6] removed from (8, 5)'s domain due to (8, 1)
# Revised: [6] removed from (8, 6)'s domain due to (8, 1)
# Revised: [6] removed from (8, 7)'s domain due to (8, 1)
# Revised: [6] removed from (8, 8)'s domain due to (8, 1)
# Processing cell (8, 4)
# Revised: [3] removed from (1, 4)'s domain due to (8, 4)
# Revised: [3] removed from (3, 4)'s domain due to (8, 4)
# Revised: [3] removed from (5, 4)'s domain due to (8, 4)
# Revised: [3] removed from (8, 0)'s domain due to (8, 4)
# Revised: [3] removed from (8, 2)'s domain due to (8, 4)
# Revised: [3] removed from (8, 3)'s domain due to (8, 4)
# Revised: [3] removed from (8, 5)'s domain due to (8, 4)
# Revised: [3] removed from (8, 6)'s domain due to (8, 4)
# Revised: [3] removed from (8, 8)'s domain due to (8, 4)
# Processing cell (1, 4)
# Revised: [2, 5, 9] removed from (2, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (3, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (5, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (7, 4)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 0)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 2)'s domain due to (1, 4)
# Revised: [2, 5] removed from (1, 3)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 5)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 6)'s domain due to (1, 4)
# Revised: [4, 6, 9] removed from (1, 7)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 8)'s domain due to (1, 4)
# Processing cell (2, 4)
# Revised: [4, 6] removed from (1, 4)'s domain due to (2, 4)
# Revised: [4] removed from (3, 4)'s domain due to (2, 4)
# Revised: [4] removed from (5, 4)'s domain due to (2, 4)
# Revised: [4] removed from (7, 4)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 0)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 2)'s domain due to (2, 4)
# Revised: [6] removed from (2, 3)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 5)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 6)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 7)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 8)'s domain due to (2, 4)
# Processing cell (3, 4)
# Revised: [6] removed from (2, 4)'s domain due to (3, 4)
# Revised: [6] removed from (5, 4)'s domain due to (3, 4)
# Forward checking successful
# MRV is (6, 6)
# Attempting to fill cell (6, 6) with domain values: [4, 6]
# Trying value 4 for cell (6, 6)
# Applying forward checking
# Processing cell (0, 4)
# Revised: [7] removed from (1, 4)'s domain due to (0, 4)
# Revised: [7] removed from (2, 4)'s domain due to (0, 4)
# Revised: [7] removed from (3, 4)'s domain due to (0, 4)
# Revised: [7] removed from (5, 4)'s domain due to (0, 4)
# Revised: [7] removed from (7, 4)'s domain due to (0, 4)
# Revised: [7] removed from (0, 0)'s domain due to (0, 4)
# Revised: [7] removed from (0, 1)'s domain due to (0, 4)
# Revised: [7] removed from (0, 2)'s domain due to (0, 4)
# Revised: [7] removed from (0, 3)'s domain due to (0, 4)
# Revised: [7] removed from (0, 5)'s domain due to (0, 4)
# Revised: [7] removed from (0, 6)'s domain due to (0, 4)
# Revised: [7] removed from (0, 7)'s domain due to (0, 4)
# Revised: [7] removed from (0, 8)'s domain due to (0, 4)
# Processing cell (1, 1)
# Revised: [1] removed from (0, 1)'s domain due to (1, 1)
# Revised: [1] removed from (3, 1)'s domain due to (1, 1)
# Revised: [1] removed from (4, 1)'s domain due to (1, 1)
# Revised: [1] removed from (5, 1)'s domain due to (1, 1)
# Revised: [1] removed from (7, 1)'s domain due to (1, 1)
# Revised: [1] removed from (1, 0)'s domain due to (1, 1)
# Revised: [1] removed from (1, 2)'s domain due to (1, 1)
# Revised: [1] removed from (1, 3)'s domain due to (1, 1)
# Revised: [1] removed from (1, 4)'s domain due to (1, 1)
# Revised: [1] removed from (1, 5)'s domain due to (1, 1)
# Revised: [1] removed from (1, 6)'s domain due to (1, 1)
# Revised: [1] removed from (1, 7)'s domain due to (1, 1)
# Revised: [1] removed from (1, 8)'s domain due to (1, 1)
# Processing cell (2, 1)
# Revised: [3] removed from (0, 1)'s domain due to (2, 1)
# Revised: [3] removed from (3, 1)'s domain due to (2, 1)
# Revised: [3] removed from (4, 1)'s domain due to (2, 1)
# Revised: [3] removed from (5, 1)'s domain due to (2, 1)
# Revised: [3] removed from (7, 1)'s domain due to (2, 1)
# Revised: [3] removed from (2, 0)'s domain due to (2, 1)
# Revised: [3] removed from (2, 2)'s domain due to (2, 1)
# Revised: [3] removed from (2, 3)'s domain due to (2, 1)
# Revised: [3] removed from (2, 4)'s domain due to (2, 1)
# Revised: [3] removed from (2, 5)'s domain due to (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# Revised: [3] removed from (2, 7)'s domain due to (2, 1)
# Revised: [3] removed from (2, 8)'s domain due to (2, 1)
# Processing cell (3, 6)
# Revised: [1] removed from (0, 6)'s domain due to (3, 6)
# Revised: [1] removed from (2, 6)'s domain due to (3, 6)
# Revised: [1] removed from (4, 6)'s domain due to (3, 6)
# Revised: [1] removed from (5, 6)'s domain due to (3, 6)
# Revised: [1] removed from (8, 6)'s domain due to (3, 6)
# Revised: [1] removed from (3, 0)'s domain due to (3, 6)
# Revised: [1] removed from (3, 2)'s domain due to (3, 6)
# Revised: [1] removed from (3, 3)'s domain due to (3, 6)
# Revised: [1] removed from (3, 4)'s domain due to (3, 6)
# Revised: [1] removed from (3, 5)'s domain due to (3, 6)
# Revised: [1] removed from (3, 7)'s domain due to (3, 6)
# Revised: [1] removed from (3, 8)'s domain due to (3, 6)
# Processing cell (4, 3)
# Revised: [4] removed from (0, 3)'s domain due to (4, 3)
# Revised: [4] removed from (1, 3)'s domain due to (4, 3)
# Revised: [4] removed from (2, 3)'s domain due to (4, 3)
# Revised: [4] removed from (3, 3)'s domain due to (4, 3)
# Revised: [4] removed from (5, 3)'s domain due to (4, 3)
# Revised: [4] removed from (7, 3)'s domain due to (4, 3)
# Revised: [4] removed from (8, 3)'s domain due to (4, 3)
# Revised: [4] removed from (4, 0)'s domain due to (4, 3)
# Revised: [4] removed from (4, 1)'s domain due to (4, 3)
# Revised: [4] removed from (4, 2)'s domain due to (4, 3)
# Revised: [4] removed from (4, 5)'s domain due to (4, 3)
# Revised: [4] removed from (4, 6)'s domain due to (4, 3)
# Revised: [4] removed from (4, 7)'s domain due to (4, 3)
# Revised: [4] removed from (4, 8)'s domain due to (4, 3)
# Processing cell (4, 4)
# Revised: [1] removed from (2, 4)'s domain due to (4, 4)
# Revised: [1] removed from (5, 4)'s domain due to (4, 4)
# Revised: [1] removed from (7, 4)'s domain due to (4, 4)
# Revised: [1] removed from (4, 0)'s domain due to (4, 4)
# Revised: [1] removed from (4, 2)'s domain due to (4, 4)
# Revised: [1] removed from (4, 5)'s domain due to (4, 4)
# Revised: [1] removed from (4, 7)'s domain due to (4, 4)
# Revised: [1] removed from (4, 8)'s domain due to (4, 4)
# Processing cell (6, 1)
# Revised: [5] removed from (0, 1)'s domain due to (6, 1)
# Revised: [5] removed from (3, 1)'s domain due to (6, 1)
# Revised: [5] removed from (4, 1)'s domain due to (6, 1)
# Revised: [5] removed from (5, 1)'s domain due to (6, 1)
# Revised: [5] removed from (7, 1)'s domain due to (6, 1)
# Revised: [5] removed from (6, 0)'s domain due to (6, 1)
# Revised: [5] removed from (6, 2)'s domain due to (6, 1)
# Revised: [5] removed from (6, 5)'s domain due to (6, 1)
# Revised: [5] removed from (6, 8)'s domain due to (6, 1)
# Processing cell (6, 3)
# Revised: [9] removed from (0, 3)'s domain due to (6, 3)
# Revised: [9] removed from (1, 3)'s domain due to (6, 3)
# Revised: [9] removed from (2, 3)'s domain due to (6, 3)
# Revised: [9] removed from (3, 3)'s domain due to (6, 3)
# Revised: [9] removed from (5, 3)'s domain due to (6, 3)
# Revised: [9] removed from (7, 3)'s domain due to (6, 3)
# Revised: [9] removed from (8, 3)'s domain due to (6, 3)
# Revised: [9] removed from (6, 0)'s domain due to (6, 3)
# Revised: [9] removed from (6, 2)'s domain due to (6, 3)
# Revised: [9] removed from (6, 5)'s domain due to (6, 3)
# Revised: [9] removed from (6, 8)'s domain due to (6, 3)
# Processing cell (6, 4)
# Revised: [8] removed from (1, 4)'s domain due to (6, 4)
# Revised: [8] removed from (2, 4)'s domain due to (6, 4)
# Revised: [8] removed from (3, 4)'s domain due to (6, 4)
# Revised: [8] removed from (5, 4)'s domain due to (6, 4)
# Revised: [8] removed from (7, 4)'s domain due to (6, 4)
# Revised: [8] removed from (6, 0)'s domain due to (6, 4)
# Revised: [8] removed from (6, 2)'s domain due to (6, 4)
# Revised: [8] removed from (6, 5)'s domain due to (6, 4)
# Revised: [8] removed from (6, 8)'s domain due to (6, 4)
# Processing cell (6, 6)
# Revised: [4] removed from (0, 6)'s domain due to (6, 6)
# Revised: [4] removed from (1, 6)'s domain due to (6, 6)
# Revised: [4] removed from (2, 6)'s domain due to (6, 6)
# Revised: [4] removed from (5, 6)'s domain due to (6, 6)
# Revised: [4] removed from (8, 6)'s domain due to (6, 6)
# Revised: [4] removed from (6, 0)'s domain due to (6, 6)
# Revised: [4] removed from (6, 2)'s domain due to (6, 6)
# Revised: [4] removed from (6, 5)'s domain due to (6, 6)
# Revised: [4] removed from (6, 8)'s domain due to (6, 6)
# Processing cell (6, 7)
# Revised: [2] removed from (0, 7)'s domain due to (6, 7)
# Revised: [2] removed from (1, 7)'s domain due to (6, 7)
# Revised: [2] removed from (2, 7)'s domain due to (6, 7)
# Revised: [2] removed from (3, 7)'s domain due to (6, 7)
# Revised: [2] removed from (4, 7)'s domain due to (6, 7)
# Revised: [2] removed from (5, 7)'s domain due to (6, 7)
# Revised: [2] removed from (8, 7)'s domain due to (6, 7)
# Revised: [2] removed from (6, 0)'s domain due to (6, 7)
# Revised: [2] removed from (6, 2)'s domain due to (6, 7)
# Revised: [2] removed from (6, 5)'s domain due to (6, 7)
# Revised: [2] removed from (6, 8)'s domain due to (6, 7)
# Processing cell (7, 6)
# Revised: [7] removed from (1, 6)'s domain due to (7, 6)
# Revised: [7] removed from (2, 6)'s domain due to (7, 6)
# Revised: [7] removed from (4, 6)'s domain due to (7, 6)
# Revised: [7] removed from (5, 6)'s domain due to (7, 6)
# Revised: [7] removed from (8, 6)'s domain due to (7, 6)
# Revised: [7] removed from (7, 0)'s domain due to (7, 6)
# Revised: [7] removed from (7, 1)'s domain due to (7, 6)
# Revised: [7] removed from (7, 2)'s domain due to (7, 6)
# Revised: [7] removed from (7, 3)'s domain due to (7, 6)
# Revised: [7] removed from (7, 5)'s domain due to (7, 6)
# Revised: [7] removed from (7, 8)'s domain due to (7, 6)
# Processing cell (7, 7)
# Revised: [3] removed from (0, 7)'s domain due to (7, 7)
# Revised: [3] removed from (1, 7)'s domain due to (7, 7)
# Revised: [3] removed from (3, 7)'s domain due to (7, 7)
# Revised: [3] removed from (4, 7)'s domain due to (7, 7)
# Revised: [3] removed from (5, 7)'s domain due to (7, 7)
# Revised: [3] removed from (8, 7)'s domain due to (7, 7)
# Revised: [3] removed from (7, 0)'s domain due to (7, 7)
# Revised: [3] removed from (7, 2)'s domain due to (7, 7)
# Revised: [3] removed from (7, 3)'s domain due to (7, 7)
# Revised: [3] removed from (7, 4)'s domain due to (7, 7)
# Revised: [3] removed from (7, 5)'s domain due to (7, 7)
# Revised: [3] removed from (7, 8)'s domain due to (7, 7)
# Processing cell (8, 1)
# Revised: [6] removed from (0, 1)'s domain due to (8, 1)
# Revised: [6] removed from (3, 1)'s domain due to (8, 1)
# Revised: [6] removed from (4, 1)'s domain due to (8, 1)
# Revised: [6] removed from (5, 1)'s domain due to (8, 1)
# Revised: [6] removed from (7, 1)'s domain due to (8, 1)
# Revised: [6] removed from (8, 0)'s domain due to (8, 1)
# Revised: [6] removed from (8, 2)'s domain due to (8, 1)
# Revised: [6] removed from (8, 3)'s domain due to (8, 1)
# Revised: [6] removed from (8, 5)'s domain due to (8, 1)
# Revised: [6] removed from (8, 6)'s domain due to (8, 1)
# Revised: [6] removed from (8, 7)'s domain due to (8, 1)
# Revised: [6] removed from (8, 8)'s domain due to (8, 1)
# Processing cell (8, 4)
# Revised: [3] removed from (1, 4)'s domain due to (8, 4)
# Revised: [3] removed from (3, 4)'s domain due to (8, 4)
# Revised: [3] removed from (5, 4)'s domain due to (8, 4)
# Revised: [3] removed from (8, 0)'s domain due to (8, 4)
# Revised: [3] removed from (8, 2)'s domain due to (8, 4)
# Revised: [3] removed from (8, 3)'s domain due to (8, 4)
# Revised: [3] removed from (8, 5)'s domain due to (8, 4)
# Revised: [3] removed from (8, 6)'s domain due to (8, 4)
# Revised: [3] removed from (8, 8)'s domain due to (8, 4)
# Processing cell (1, 4)
# Revised: [2, 5, 9] removed from (2, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (3, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (5, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (7, 4)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 0)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 2)'s domain due to (1, 4)
# Revised: [2, 5] removed from (1, 3)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 5)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (1, 6)'s domain due to (1, 4)
# Revised: [4, 6, 9] removed from (1, 7)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 8)'s domain due to (1, 4)
# Processing cell (2, 4)
# Revised: [4, 6] removed from (1, 4)'s domain due to (2, 4)
# Revised: [4] removed from (3, 4)'s domain due to (2, 4)
# Revised: [4] removed from (5, 4)'s domain due to (2, 4)
# Revised: [4] removed from (7, 4)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 0)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 2)'s domain due to (2, 4)
# Revised: [6] removed from (2, 3)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 5)'s domain due to (2, 4)
# Revised: [6] removed from (2, 6)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 7)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 8)'s domain due to (2, 4)
# Processing cell (3, 4)
# Revised: [6] removed from (2, 4)'s domain due to (3, 4)
# Revised: [6] removed from (5, 4)'s domain due to (3, 4)
# Forward checking successful
# MRV is (6, 8)
# Attempting to fill cell (6, 8) with domain values: [6, 1]
# Trying value 6 for cell (6, 8)
# Applying forward checking
# Processing cell (0, 4)
# Revised: [7] removed from (1, 4)'s domain due to (0, 4)
# Revised: [7] removed from (2, 4)'s domain due to (0, 4)
# Revised: [7] removed from (3, 4)'s domain due to (0, 4)
# Revised: [7] removed from (5, 4)'s domain due to (0, 4)
# Revised: [7] removed from (7, 4)'s domain due to (0, 4)
# Revised: [7] removed from (0, 0)'s domain due to (0, 4)
# Revised: [7] removed from (0, 1)'s domain due to (0, 4)
# Revised: [7] removed from (0, 2)'s domain due to (0, 4)
# Revised: [7] removed from (0, 3)'s domain due to (0, 4)
# Revised: [7] removed from (0, 5)'s domain due to (0, 4)
# Revised: [7] removed from (0, 6)'s domain due to (0, 4)
# Revised: [7] removed from (0, 7)'s domain due to (0, 4)
# Revised: [7] removed from (0, 8)'s domain due to (0, 4)
# Processing cell (1, 1)
# Revised: [1] removed from (0, 1)'s domain due to (1, 1)
# Revised: [1] removed from (3, 1)'s domain due to (1, 1)
# Revised: [1] removed from (4, 1)'s domain due to (1, 1)
# Revised: [1] removed from (5, 1)'s domain due to (1, 1)
# Revised: [1] removed from (7, 1)'s domain due to (1, 1)
# Revised: [1] removed from (1, 0)'s domain due to (1, 1)
# Revised: [1] removed from (1, 2)'s domain due to (1, 1)
# Revised: [1] removed from (1, 3)'s domain due to (1, 1)
# Revised: [1] removed from (1, 4)'s domain due to (1, 1)
# Revised: [1] removed from (1, 5)'s domain due to (1, 1)
# Revised: [1] removed from (1, 6)'s domain due to (1, 1)
# Revised: [1] removed from (1, 7)'s domain due to (1, 1)
# Revised: [1] removed from (1, 8)'s domain due to (1, 1)
# Processing cell (2, 1)
# Revised: [3] removed from (0, 1)'s domain due to (2, 1)
# Revised: [3] removed from (3, 1)'s domain due to (2, 1)
# Revised: [3] removed from (4, 1)'s domain due to (2, 1)
# Revised: [3] removed from (5, 1)'s domain due to (2, 1)
# Revised: [3] removed from (7, 1)'s domain due to (2, 1)
# Revised: [3] removed from (2, 0)'s domain due to (2, 1)
# Revised: [3] removed from (2, 2)'s domain due to (2, 1)
# Revised: [3] removed from (2, 3)'s domain due to (2, 1)
# Revised: [3] removed from (2, 4)'s domain due to (2, 1)
# Revised: [3] removed from (2, 5)'s domain due to (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# Revised: [3] removed from (2, 7)'s domain due to (2, 1)
# Revised: [3] removed from (2, 8)'s domain due to (2, 1)
# Processing cell (3, 6)
# Revised: [1] removed from (0, 6)'s domain due to (3, 6)
# Revised: [1] removed from (2, 6)'s domain due to (3, 6)
# Revised: [1] removed from (4, 6)'s domain due to (3, 6)
# Revised: [1] removed from (5, 6)'s domain due to (3, 6)
# Revised: [1] removed from (8, 6)'s domain due to (3, 6)
# Revised: [1] removed from (3, 0)'s domain due to (3, 6)
# Revised: [1] removed from (3, 2)'s domain due to (3, 6)
# Revised: [1] removed from (3, 3)'s domain due to (3, 6)
# Revised: [1] removed from (3, 4)'s domain due to (3, 6)
# Revised: [1] removed from (3, 5)'s domain due to (3, 6)
# Revised: [1] removed from (3, 7)'s domain due to (3, 6)
# Revised: [1] removed from (3, 8)'s domain due to (3, 6)
# Processing cell (4, 3)
# Revised: [4] removed from (0, 3)'s domain due to (4, 3)
# Revised: [4] removed from (1, 3)'s domain due to (4, 3)
# Revised: [4] removed from (2, 3)'s domain due to (4, 3)
# Revised: [4] removed from (3, 3)'s domain due to (4, 3)
# Revised: [4] removed from (5, 3)'s domain due to (4, 3)
# Revised: [4] removed from (7, 3)'s domain due to (4, 3)
# Revised: [4] removed from (8, 3)'s domain due to (4, 3)
# Revised: [4] removed from (4, 0)'s domain due to (4, 3)
# Revised: [4] removed from (4, 1)'s domain due to (4, 3)
# Revised: [4] removed from (4, 2)'s domain due to (4, 3)
# Revised: [4] removed from (4, 5)'s domain due to (4, 3)
# Revised: [4] removed from (4, 6)'s domain due to (4, 3)
# Revised: [4] removed from (4, 7)'s domain due to (4, 3)
# Revised: [4] removed from (4, 8)'s domain due to (4, 3)
# Processing cell (4, 4)
# Revised: [1] removed from (2, 4)'s domain due to (4, 4)
# Revised: [1] removed from (5, 4)'s domain due to (4, 4)
# Revised: [1] removed from (7, 4)'s domain due to (4, 4)
# Revised: [1] removed from (4, 0)'s domain due to (4, 4)
# Revised: [1] removed from (4, 2)'s domain due to (4, 4)
# Revised: [1] removed from (4, 5)'s domain due to (4, 4)
# Revised: [1] removed from (4, 7)'s domain due to (4, 4)
# Revised: [1] removed from (4, 8)'s domain due to (4, 4)
# Processing cell (6, 1)
# Revised: [5] removed from (0, 1)'s domain due to (6, 1)
# Revised: [5] removed from (3, 1)'s domain due to (6, 1)
# Revised: [5] removed from (4, 1)'s domain due to (6, 1)
# Revised: [5] removed from (5, 1)'s domain due to (6, 1)
# Revised: [5] removed from (7, 1)'s domain due to (6, 1)
# Revised: [5] removed from (6, 0)'s domain due to (6, 1)
# Revised: [5] removed from (6, 2)'s domain due to (6, 1)
# Revised: [5] removed from (6, 5)'s domain due to (6, 1)
# Processing cell (6, 3)
# Revised: [9] removed from (0, 3)'s domain due to (6, 3)
# Revised: [9] removed from (1, 3)'s domain due to (6, 3)
# Revised: [9] removed from (2, 3)'s domain due to (6, 3)
# Revised: [9] removed from (3, 3)'s domain due to (6, 3)
# Revised: [9] removed from (5, 3)'s domain due to (6, 3)
# Revised: [9] removed from (7, 3)'s domain due to (6, 3)
# Revised: [9] removed from (8, 3)'s domain due to (6, 3)
# Revised: [9] removed from (6, 0)'s domain due to (6, 3)
# Revised: [9] removed from (6, 2)'s domain due to (6, 3)
# Revised: [9] removed from (6, 5)'s domain due to (6, 3)
# Processing cell (6, 4)
# Revised: [8] removed from (1, 4)'s domain due to (6, 4)
# Revised: [8] removed from (2, 4)'s domain due to (6, 4)
# Revised: [8] removed from (3, 4)'s domain due to (6, 4)
# Revised: [8] removed from (5, 4)'s domain due to (6, 4)
# Revised: [8] removed from (7, 4)'s domain due to (6, 4)
# Revised: [8] removed from (6, 0)'s domain due to (6, 4)
# Revised: [8] removed from (6, 2)'s domain due to (6, 4)
# Revised: [8] removed from (6, 5)'s domain due to (6, 4)
# Processing cell (6, 6)
# Revised: [4] removed from (0, 6)'s domain due to (6, 6)
# Revised: [4] removed from (1, 6)'s domain due to (6, 6)
# Revised: [4] removed from (2, 6)'s domain due to (6, 6)
# Revised: [4] removed from (5, 6)'s domain due to (6, 6)
# Revised: [4] removed from (8, 6)'s domain due to (6, 6)
# Revised: [4] removed from (6, 0)'s domain due to (6, 6)
# Revised: [4] removed from (6, 2)'s domain due to (6, 6)
# Revised: [4] removed from (6, 5)'s domain due to (6, 6)
# Processing cell (6, 7)
# Revised: [2] removed from (0, 7)'s domain due to (6, 7)
# Revised: [2] removed from (1, 7)'s domain due to (6, 7)
# Revised: [2] removed from (2, 7)'s domain due to (6, 7)
# Revised: [2] removed from (3, 7)'s domain due to (6, 7)
# Revised: [2] removed from (4, 7)'s domain due to (6, 7)
# Revised: [2] removed from (5, 7)'s domain due to (6, 7)
# Revised: [2] removed from (8, 7)'s domain due to (6, 7)
# Revised: [2] removed from (6, 0)'s domain due to (6, 7)
# Revised: [2] removed from (6, 2)'s domain due to (6, 7)
# Revised: [2] removed from (6, 5)'s domain due to (6, 7)
# Processing cell (6, 8)
# Revised: [6] removed from (0, 8)'s domain due to (6, 8)
# Revised: [6] removed from (1, 8)'s domain due to (6, 8)
# Revised: [6] removed from (2, 8)'s domain due to (6, 8)
# Revised: [6] removed from (3, 8)'s domain due to (6, 8)
# Revised: [6] removed from (4, 8)'s domain due to (6, 8)
# Revised: [6] removed from (5, 8)'s domain due to (6, 8)
# Revised: [6] removed from (7, 8)'s domain due to (6, 8)
# Revised: [6] removed from (8, 8)'s domain due to (6, 8)
# Revised: [6] removed from (6, 0)'s domain due to (6, 8)
# Revised: [6] removed from (6, 2)'s domain due to (6, 8)
# Revised: [6] removed from (6, 5)'s domain due to (6, 8)
# Processing cell (7, 6)
# Revised: [7] removed from (1, 6)'s domain due to (7, 6)
# Revised: [7] removed from (2, 6)'s domain due to (7, 6)
# Revised: [7] removed from (4, 6)'s domain due to (7, 6)
# Revised: [7] removed from (5, 6)'s domain due to (7, 6)
# Revised: [7] removed from (8, 6)'s domain due to (7, 6)
# Revised: [7] removed from (7, 0)'s domain due to (7, 6)
# Revised: [7] removed from (7, 1)'s domain due to (7, 6)
# Revised: [7] removed from (7, 2)'s domain due to (7, 6)
# Revised: [7] removed from (7, 3)'s domain due to (7, 6)
# Revised: [7] removed from (7, 5)'s domain due to (7, 6)
# Revised: [7] removed from (7, 8)'s domain due to (7, 6)
# Processing cell (7, 7)
# Revised: [3] removed from (0, 7)'s domain due to (7, 7)
# Revised: [3] removed from (1, 7)'s domain due to (7, 7)
# Revised: [3] removed from (3, 7)'s domain due to (7, 7)
# Revised: [3] removed from (4, 7)'s domain due to (7, 7)
# Revised: [3] removed from (5, 7)'s domain due to (7, 7)
# Revised: [3] removed from (8, 7)'s domain due to (7, 7)
# Revised: [3] removed from (7, 0)'s domain due to (7, 7)
# Revised: [3] removed from (7, 2)'s domain due to (7, 7)
# Revised: [3] removed from (7, 3)'s domain due to (7, 7)
# Revised: [3] removed from (7, 4)'s domain due to (7, 7)
# Revised: [3] removed from (7, 5)'s domain due to (7, 7)
# Revised: [3] removed from (7, 8)'s domain due to (7, 7)
# Processing cell (8, 1)
# Revised: [6] removed from (0, 1)'s domain due to (8, 1)
# Revised: [6] removed from (3, 1)'s domain due to (8, 1)
# Revised: [6] removed from (4, 1)'s domain due to (8, 1)
# Revised: [6] removed from (5, 1)'s domain due to (8, 1)
# Revised: [6] removed from (7, 1)'s domain due to (8, 1)
# Revised: [6] removed from (8, 0)'s domain due to (8, 1)
# Revised: [6] removed from (8, 2)'s domain due to (8, 1)
# Revised: [6] removed from (8, 3)'s domain due to (8, 1)
# Revised: [6] removed from (8, 5)'s domain due to (8, 1)
# Revised: [6] removed from (8, 6)'s domain due to (8, 1)
# Revised: [6] removed from (8, 7)'s domain due to (8, 1)
# Processing cell (8, 4)
# Revised: [3] removed from (1, 4)'s domain due to (8, 4)
# Revised: [3] removed from (3, 4)'s domain due to (8, 4)
# Revised: [3] removed from (5, 4)'s domain due to (8, 4)
# Revised: [3] removed from (8, 0)'s domain due to (8, 4)
# Revised: [3] removed from (8, 2)'s domain due to (8, 4)
# Revised: [3] removed from (8, 3)'s domain due to (8, 4)
# Revised: [3] removed from (8, 5)'s domain due to (8, 4)
# Revised: [3] removed from (8, 6)'s domain due to (8, 4)
# Revised: [3] removed from (8, 8)'s domain due to (8, 4)
# Processing cell (1, 4)
# Revised: [2, 5, 9] removed from (2, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (3, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (5, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (7, 4)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 0)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 2)'s domain due to (1, 4)
# Revised: [2, 5] removed from (1, 3)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 5)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (1, 6)'s domain due to (1, 4)
# Revised: [4, 6, 9] removed from (1, 7)'s domain due to (1, 4)
# Revised: [2, 4, 9] removed from (1, 8)'s domain due to (1, 4)
# Processing cell (2, 4)
# Revised: [4, 6] removed from (1, 4)'s domain due to (2, 4)
# Revised: [4] removed from (3, 4)'s domain due to (2, 4)
# Revised: [4] removed from (5, 4)'s domain due to (2, 4)
# Revised: [4] removed from (7, 4)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 0)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 2)'s domain due to (2, 4)
# Revised: [6] removed from (2, 3)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 5)'s domain due to (2, 4)
# Revised: [6] removed from (2, 6)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 7)'s domain due to (2, 4)
# Revised: [4] removed from (2, 8)'s domain due to (2, 4)
# Processing cell (3, 4)
# Revised: [6] removed from (2, 4)'s domain due to (3, 4)
# Revised: [6] removed from (5, 4)'s domain due to (3, 4)
# Forward checking successful
# MRV is (6, 5)
# Attempting to fill cell (6, 5) with domain values: [1, 7]
# Trying value 1 for cell (6, 5)
# Applying forward checking
# Processing cell (0, 4)
# Revised: [7] removed from (1, 4)'s domain due to (0, 4)
# Revised: [7] removed from (2, 4)'s domain due to (0, 4)
# Revised: [7] removed from (3, 4)'s domain due to (0, 4)
# Revised: [7] removed from (5, 4)'s domain due to (0, 4)
# Revised: [7] removed from (7, 4)'s domain due to (0, 4)
# Revised: [7] removed from (0, 0)'s domain due to (0, 4)
# Revised: [7] removed from (0, 1)'s domain due to (0, 4)
# Revised: [7] removed from (0, 2)'s domain due to (0, 4)
# Revised: [7] removed from (0, 3)'s domain due to (0, 4)
# Revised: [7] removed from (0, 5)'s domain due to (0, 4)
# Revised: [7] removed from (0, 6)'s domain due to (0, 4)
# Revised: [7] removed from (0, 7)'s domain due to (0, 4)
# Revised: [7] removed from (0, 8)'s domain due to (0, 4)
# Processing cell (1, 1)
# Revised: [1] removed from (0, 1)'s domain due to (1, 1)
# Revised: [1] removed from (3, 1)'s domain due to (1, 1)
# Revised: [1] removed from (4, 1)'s domain due to (1, 1)
# Revised: [1] removed from (5, 1)'s domain due to (1, 1)
# Revised: [1] removed from (7, 1)'s domain due to (1, 1)
# Revised: [1] removed from (1, 0)'s domain due to (1, 1)
# Revised: [1] removed from (1, 2)'s domain due to (1, 1)
# Revised: [1] removed from (1, 3)'s domain due to (1, 1)
# Revised: [1] removed from (1, 4)'s domain due to (1, 1)
# Revised: [1] removed from (1, 5)'s domain due to (1, 1)
# Revised: [1] removed from (1, 6)'s domain due to (1, 1)
# Revised: [1] removed from (1, 7)'s domain due to (1, 1)
# Revised: [1] removed from (1, 8)'s domain due to (1, 1)
# Processing cell (2, 1)
# Revised: [3] removed from (0, 1)'s domain due to (2, 1)
# Revised: [3] removed from (3, 1)'s domain due to (2, 1)
# Revised: [3] removed from (4, 1)'s domain due to (2, 1)
# Revised: [3] removed from (5, 1)'s domain due to (2, 1)
# Revised: [3] removed from (7, 1)'s domain due to (2, 1)
# Revised: [3] removed from (2, 0)'s domain due to (2, 1)
# Revised: [3] removed from (2, 2)'s domain due to (2, 1)
# Revised: [3] removed from (2, 3)'s domain due to (2, 1)
# Revised: [3] removed from (2, 4)'s domain due to (2, 1)
# Revised: [3] removed from (2, 5)'s domain due to (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# Revised: [3] removed from (2, 7)'s domain due to (2, 1)
# Revised: [3] removed from (2, 8)'s domain due to (2, 1)
# Processing cell (3, 6)
# Revised: [1] removed from (0, 6)'s domain due to (3, 6)
# Revised: [1] removed from (2, 6)'s domain due to (3, 6)
# Revised: [1] removed from (4, 6)'s domain due to (3, 6)
# Revised: [1] removed from (5, 6)'s domain due to (3, 6)
# Revised: [1] removed from (8, 6)'s domain due to (3, 6)
# Revised: [1] removed from (3, 0)'s domain due to (3, 6)
# Revised: [1] removed from (3, 2)'s domain due to (3, 6)
# Revised: [1] removed from (3, 3)'s domain due to (3, 6)
# Revised: [1] removed from (3, 4)'s domain due to (3, 6)
# Revised: [1] removed from (3, 5)'s domain due to (3, 6)
# Revised: [1] removed from (3, 7)'s domain due to (3, 6)
# Revised: [1] removed from (3, 8)'s domain due to (3, 6)
# Processing cell (4, 3)
# Revised: [4] removed from (0, 3)'s domain due to (4, 3)
# Revised: [4] removed from (1, 3)'s domain due to (4, 3)
# Revised: [4] removed from (2, 3)'s domain due to (4, 3)
# Revised: [4] removed from (3, 3)'s domain due to (4, 3)
# Revised: [4] removed from (5, 3)'s domain due to (4, 3)
# Revised: [4] removed from (7, 3)'s domain due to (4, 3)
# Revised: [4] removed from (8, 3)'s domain due to (4, 3)
# Revised: [4] removed from (4, 0)'s domain due to (4, 3)
# Revised: [4] removed from (4, 1)'s domain due to (4, 3)
# Revised: [4] removed from (4, 2)'s domain due to (4, 3)
# Revised: [4] removed from (4, 5)'s domain due to (4, 3)
# Revised: [4] removed from (4, 6)'s domain due to (4, 3)
# Revised: [4] removed from (4, 7)'s domain due to (4, 3)
# Revised: [4] removed from (4, 8)'s domain due to (4, 3)
# Processing cell (4, 4)
# Revised: [1] removed from (2, 4)'s domain due to (4, 4)
# Revised: [1] removed from (5, 4)'s domain due to (4, 4)
# Revised: [1] removed from (7, 4)'s domain due to (4, 4)
# Revised: [1] removed from (4, 0)'s domain due to (4, 4)
# Revised: [1] removed from (4, 2)'s domain due to (4, 4)
# Revised: [1] removed from (4, 5)'s domain due to (4, 4)
# Revised: [1] removed from (4, 7)'s domain due to (4, 4)
# Revised: [1] removed from (4, 8)'s domain due to (4, 4)
# Processing cell (6, 1)
# Revised: [5] removed from (0, 1)'s domain due to (6, 1)
# Revised: [5] removed from (3, 1)'s domain due to (6, 1)
# Revised: [5] removed from (4, 1)'s domain due to (6, 1)
# Revised: [5] removed from (5, 1)'s domain due to (6, 1)
# Revised: [5] removed from (7, 1)'s domain due to (6, 1)
# Revised: [5] removed from (6, 0)'s domain due to (6, 1)
# Revised: [5] removed from (6, 2)'s domain due to (6, 1)
# Processing cell (6, 3)
# Revised: [9] removed from (0, 3)'s domain due to (6, 3)
# Revised: [9] removed from (1, 3)'s domain due to (6, 3)
# Revised: [9] removed from (2, 3)'s domain due to (6, 3)
# Revised: [9] removed from (3, 3)'s domain due to (6, 3)
# Revised: [9] removed from (5, 3)'s domain due to (6, 3)
# Revised: [9] removed from (7, 3)'s domain due to (6, 3)
# Revised: [9] removed from (8, 3)'s domain due to (6, 3)
# Revised: [9] removed from (6, 0)'s domain due to (6, 3)
# Revised: [9] removed from (6, 2)'s domain due to (6, 3)
# Processing cell (6, 4)
# Revised: [8] removed from (1, 4)'s domain due to (6, 4)
# Revised: [8] removed from (2, 4)'s domain due to (6, 4)
# Revised: [8] removed from (3, 4)'s domain due to (6, 4)
# Revised: [8] removed from (5, 4)'s domain due to (6, 4)
# Revised: [8] removed from (7, 4)'s domain due to (6, 4)
# Revised: [8] removed from (6, 0)'s domain due to (6, 4)
# Revised: [8] removed from (6, 2)'s domain due to (6, 4)
# Processing cell (6, 5)
# Revised: [1] removed from (0, 5)'s domain due to (6, 5)
# Revised: [1] removed from (2, 5)'s domain due to (6, 5)
# Revised: [1] removed from (5, 5)'s domain due to (6, 5)
# Revised: [1] removed from (7, 5)'s domain due to (6, 5)
# Revised: [1] removed from (8, 5)'s domain due to (6, 5)
# Revised: [1] removed from (6, 0)'s domain due to (6, 5)
# Revised: [1] removed from (6, 2)'s domain due to (6, 5)
# Processing cell (6, 6)
# Revised: [4] removed from (0, 6)'s domain due to (6, 6)
# Revised: [4] removed from (1, 6)'s domain due to (6, 6)
# Revised: [4] removed from (2, 6)'s domain due to (6, 6)
# Revised: [4] removed from (5, 6)'s domain due to (6, 6)
# Revised: [4] removed from (8, 6)'s domain due to (6, 6)
# Revised: [4] removed from (6, 0)'s domain due to (6, 6)
# Revised: [4] removed from (6, 2)'s domain due to (6, 6)
# Processing cell (6, 7)
# Revised: [2] removed from (0, 7)'s domain due to (6, 7)
# Revised: [2] removed from (1, 7)'s domain due to (6, 7)
# Revised: [2] removed from (2, 7)'s domain due to (6, 7)
# Revised: [2] removed from (3, 7)'s domain due to (6, 7)
# Revised: [2] removed from (4, 7)'s domain due to (6, 7)
# Revised: [2] removed from (5, 7)'s domain due to (6, 7)
# Revised: [2] removed from (8, 7)'s domain due to (6, 7)
# Revised: [2] removed from (6, 0)'s domain due to (6, 7)
# Revised: [2] removed from (6, 2)'s domain due to (6, 7)
# Processing cell (6, 8)
# Revised: [6] removed from (0, 8)'s domain due to (6, 8)
# Revised: [6] removed from (1, 8)'s domain due to (6, 8)
# Revised: [6] removed from (2, 8)'s domain due to (6, 8)
# Revised: [6] removed from (3, 8)'s domain due to (6, 8)
# Revised: [6] removed from (4, 8)'s domain due to (6, 8)
# Revised: [6] removed from (5, 8)'s domain due to (6, 8)
# Revised: [6] removed from (7, 8)'s domain due to (6, 8)
# Revised: [6] removed from (8, 8)'s domain due to (6, 8)
# Revised: [6] removed from (6, 0)'s domain due to (6, 8)
# Revised: [6] removed from (6, 2)'s domain due to (6, 8)
# Processing cell (7, 6)
# Revised: [7] removed from (1, 6)'s domain due to (7, 6)
# Revised: [7] removed from (2, 6)'s domain due to (7, 6)
# Revised: [7] removed from (4, 6)'s domain due to (7, 6)
# Revised: [7] removed from (5, 6)'s domain due to (7, 6)
# Revised: [7] removed from (8, 6)'s domain due to (7, 6)
# Revised: [7] removed from (7, 0)'s domain due to (7, 6)
# Revised: [7] removed from (7, 1)'s domain due to (7, 6)
# Revised: [7] removed from (7, 2)'s domain due to (7, 6)
# Revised: [7] removed from (7, 3)'s domain due to (7, 6)
# Revised: [7] removed from (7, 5)'s domain due to (7, 6)
# Revised: [7] removed from (7, 8)'s domain due to (7, 6)
# Processing cell (7, 7)
# Revised: [3] removed from (0, 7)'s domain due to (7, 7)
# Revised: [3] removed from (1, 7)'s domain due to (7, 7)
# Revised: [3] removed from (3, 7)'s domain due to (7, 7)
# Revised: [3] removed from (4, 7)'s domain due to (7, 7)
# Revised: [3] removed from (5, 7)'s domain due to (7, 7)
# Revised: [3] removed from (8, 7)'s domain due to (7, 7)
# Revised: [3] removed from (7, 0)'s domain due to (7, 7)
# Revised: [3] removed from (7, 2)'s domain due to (7, 7)
# Revised: [3] removed from (7, 3)'s domain due to (7, 7)
# Revised: [3] removed from (7, 4)'s domain due to (7, 7)
# Revised: [3] removed from (7, 5)'s domain due to (7, 7)
# Revised: [3] removed from (7, 8)'s domain due to (7, 7)
# Processing cell (8, 1)
# Revised: [6] removed from (0, 1)'s domain due to (8, 1)
# Revised: [6] removed from (3, 1)'s domain due to (8, 1)
# Revised: [6] removed from (4, 1)'s domain due to (8, 1)
# Revised: [6] removed from (5, 1)'s domain due to (8, 1)
# Revised: [6] removed from (7, 1)'s domain due to (8, 1)
# Revised: [6] removed from (8, 0)'s domain due to (8, 1)
# Revised: [6] removed from (8, 2)'s domain due to (8, 1)
# Revised: [6] removed from (8, 3)'s domain due to (8, 1)
# Revised: [6] removed from (8, 5)'s domain due to (8, 1)
# Revised: [6] removed from (8, 6)'s domain due to (8, 1)
# Revised: [6] removed from (8, 7)'s domain due to (8, 1)
# Processing cell (8, 4)
# Revised: [3] removed from (1, 4)'s domain due to (8, 4)
# Revised: [3] removed from (3, 4)'s domain due to (8, 4)
# Revised: [3] removed from (5, 4)'s domain due to (8, 4)
# Revised: [3] removed from (8, 0)'s domain due to (8, 4)
# Revised: [3] removed from (8, 2)'s domain due to (8, 4)
# Revised: [3] removed from (8, 3)'s domain due to (8, 4)
# Revised: [3] removed from (8, 5)'s domain due to (8, 4)
# Revised: [3] removed from (8, 6)'s domain due to (8, 4)
# Revised: [3] removed from (8, 8)'s domain due to (8, 4)
# Processing cell (1, 4)
# Revised: [2, 5, 9] removed from (2, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (3, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (5, 4)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (7, 4)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 0)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 2)'s domain due to (1, 4)
# Revised: [2, 5] removed from (1, 3)'s domain due to (1, 4)
# Revised: [2, 4, 6, 9] removed from (1, 5)'s domain due to (1, 4)
# Revised: [2, 5, 9] removed from (1, 6)'s domain due to (1, 4)
# Revised: [4, 6, 9] removed from (1, 7)'s domain due to (1, 4)
# Revised: [2, 4, 9] removed from (1, 8)'s domain due to (1, 4)
# Processing cell (2, 4)
# Revised: [4, 6] removed from (1, 4)'s domain due to (2, 4)
# Revised: [4] removed from (3, 4)'s domain due to (2, 4)
# Revised: [4] removed from (5, 4)'s domain due to (2, 4)
# Revised: [4] removed from (7, 4)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 0)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 2)'s domain due to (2, 4)
# Revised: [6] removed from (2, 3)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 5)'s domain due to (2, 4)
# Revised: [6] removed from (2, 6)'s domain due to (2, 4)
# Revised: [4, 6] removed from (2, 7)'s domain due to (2, 4)
# Revised: [4] removed from (2, 8)'s domain due to (2, 4)
# Processing cell (3, 4)
# Revised: [6] removed from (2, 4)'s domain due to (3, 4)
# Revised: [6] removed from (5, 4)'s domain due to (3, 4)
# Forward checking successful
# MRV is (6, 0)
# Attempting to fill cell (6, 0) with domain values: [7, 3]
# Trying value 7 for cell (6, 0)
# Applying forward checking
# Processing cell (0, 4)
# Revised: [7] removed from (1, 4)'s domain due to (0, 4)
# Revised: [7] removed from (2, 4)'s domain due to (0, 4)
# Revised: [7] removed from (3, 4)'s domain due to (0, 4)
# Revised: [7] removed from (5, 4)'s domain due to (0, 4)
# Revised: [7] removed from (7, 4)'s domain due to (0, 4)
# Revised: [7] removed from (0, 0)'s domain due to (0, 4)
# Revised: [7] removed from (0, 1)'s domain due to (0, 4)
# Revised: [7] removed from (0, 2)'s domain due to (0, 4)
# Revised: [7] removed from (0, 3)'s domain due to (0, 4)
# Revised: [7] removed from (0, 5)'s domain due to (0, 4)
# Revised: [7] removed from (0, 6)'s domain due to (0, 4)
# Revised: [7] removed from (0, 7)'s domain due to (0, 4)
# Revised: [7] removed from (0, 8)'s domain due to (0, 4)
# Processing cell (1, 1)
# Revised: [1] removed from (0, 1)'s domain due to (1, 1)
# Revised: [1] removed from (3, 1)'s domain due to (1, 1)
# Revised: [1] removed from (4, 1)'s domain due to (1, 1)
# Revised: [1] removed from (5, 1)'s domain due to (1, 1)
# Revised: [1] removed from (7, 1)'s domain due to (1, 1)
# Revised: [1] removed from (1, 0)'s domain due to (1, 1)
# Revised: [1] removed from (1, 2)'s domain due to (1, 1)
# Revised: [1] removed from (1, 3)'s domain due to (1, 1)
# Revised: [1] removed from (1, 4)'s domain due to (1, 1)
# Revised: [1] removed from (1, 5)'s domain due to (1, 1)
# Revised: [1] removed from (1, 6)'s domain due to (1, 1)
# Revised: [1] removed from (1, 7)'s domain due to (1, 1)
# Revised: [1] removed from (1, 8)'s domain due to (1, 1)
# Processing cell (2, 1)
# Revised: [3] removed from (0, 1)'s domain due to (2, 1)
# Revised: [3] removed from (3, 1)'s domain due to (2, 1)
# Revised: [3] removed from (4, 1)'s domain due to (2, 1)
# Revised: [3] removed from (5, 1)'s domain due to (2, 1)
# Revised: [3] removed from (7, 1)'s domain due to (2, 1)
# Revised: [3] removed from (2, 0)'s domain due to (2, 1)
# Revised: [3] removed from (2, 2)'s domain due to (2, 1)
# Revised: [3] removed from (2, 3)'s domain due to (2, 1)
# Revised: [3] removed from (2, 4)'s domain due to (2, 1)
# Revised: [3] removed from (2, 5)'s domain due to (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# ...
# Revised: [8] removed from (2, 8)'s domain due to (2, 7)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Revised: [8] removed from (5, 6)'s domain due to (3, 6)
# Revised: [8] removed from (8, 6)'s domain due to (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Revised: [4] removed from (5, 6)'s domain due to (4, 6)
# Revised: [4] removed from (8, 6)'s domain due to (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Revised: [1] removed from (5, 6)'s domain due to (5, 2)
# Processing cell (5, 3)
# Revised: [3] removed from (5, 6)'s domain due to (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Revised: [5] removed from (5, 6)'s domain due to (5, 5)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Revised: [6] removed from (2, 8)'s domain due to (5, 8)
# Revised: [6] removed from (5, 6)'s domain due to (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Revised: [1] removed from (8, 6)'s domain due to (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Revised: [3] removed from (8, 6)'s domain due to (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Revised: [9] removed from (8, 6)'s domain due to (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 7)
# Revised: [6] removed from (8, 6)'s domain due to (8, 7)
# Processing cell (8, 8)
# Processing cell (2, 6)
# Revised: [5] removed from (8, 6)'s domain due to (2, 6)
# Forward checking successful
# MRV is (2, 8)
# Attempting to fill cell (2, 8) with domain values: [5]
# Trying value 5 for cell (2, 8)
# Applying forward checking
# Processing cell (0, 0)
# Processing cell (0, 1)
# Processing cell (0, 2)
# Processing cell (0, 3)
# Processing cell (0, 4)
# Processing cell (0, 5)
# Processing cell (0, 6)
# Revised: [2] removed from (2, 6)'s domain due to (0, 6)
# Revised: [2] removed from (5, 6)'s domain due to (0, 6)
# Revised: [2] removed from (8, 6)'s domain due to (0, 6)
# Processing cell (0, 7)
# Processing cell (0, 8)
# Processing cell (1, 0)
# Processing cell (1, 1)
# Processing cell (1, 2)
# Processing cell (1, 3)
# Processing cell (1, 4)
# Processing cell (1, 5)
# Processing cell (1, 6)
# Revised: [7] removed from (2, 6)'s domain due to (1, 6)
# Revised: [7] removed from (5, 6)'s domain due to (1, 6)
# Revised: [7] removed from (8, 6)'s domain due to (1, 6)
# Processing cell (1, 7)
# Processing cell (1, 8)
# Processing cell (2, 0)
# Revised: [1] removed from (2, 6)'s domain due to (2, 0)
# Processing cell (2, 1)
# Revised: [3] removed from (2, 6)'s domain due to (2, 1)
# Processing cell (2, 2)
# Processing cell (2, 3)
# Revised: [4] removed from (2, 6)'s domain due to (2, 3)
# Processing cell (2, 4)
# Processing cell (2, 5)
# Revised: [9] removed from (2, 6)'s domain due to (2, 5)
# Processing cell (2, 7)
# Revised: [8] removed from (2, 6)'s domain due to (2, 7)
# Processing cell (2, 8)
# Revised: [5] removed from (2, 6)'s domain due to (2, 8)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Revised: [8] removed from (5, 6)'s domain due to (3, 6)
# Revised: [8] removed from (8, 6)'s domain due to (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Revised: [4] removed from (5, 6)'s domain due to (4, 6)
# Revised: [4] removed from (8, 6)'s domain due to (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Revised: [1] removed from (5, 6)'s domain due to (5, 2)
# Processing cell (5, 3)
# Revised: [3] removed from (5, 6)'s domain due to (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Revised: [5] removed from (5, 6)'s domain due to (5, 5)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Revised: [6] removed from (5, 6)'s domain due to (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Revised: [1] removed from (8, 6)'s domain due to (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Revised: [3] removed from (8, 6)'s domain due to (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Revised: [9] removed from (8, 6)'s domain due to (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 7)
# Revised: [6] removed from (8, 6)'s domain due to (8, 7)
# Processing cell (8, 8)
# Processing cell (2, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (2, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (2, 6)
# Processing cell (2, 6)
# Processing cell (2, 6)
# Processing cell (2, 6)
# Processing cell (2, 6)
# Processing cell (2, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (5, 6)
# Processing cell (5, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Forward checking successful
# MRV is (2, 6)
# Attempting to fill cell (2, 6) with domain values: [6]
# Trying value 6 for cell (2, 6)
# Applying forward checking
# Processing cell (0, 0)
# Processing cell (0, 1)
# Processing cell (0, 2)
# Processing cell (0, 3)
# Processing cell (0, 4)
# Processing cell (0, 5)
# Processing cell (0, 6)
# Revised: [2] removed from (5, 6)'s domain due to (0, 6)
# Revised: [2] removed from (8, 6)'s domain due to (0, 6)
# Processing cell (0, 7)
# Processing cell (0, 8)
# Processing cell (1, 0)
# Processing cell (1, 1)
# Processing cell (1, 2)
# Processing cell (1, 3)
# Processing cell (1, 4)
# Processing cell (1, 5)
# Processing cell (1, 6)
# Revised: [7] removed from (5, 6)'s domain due to (1, 6)
# Revised: [7] removed from (8, 6)'s domain due to (1, 6)
# Processing cell (1, 7)
# Processing cell (1, 8)
# Processing cell (2, 0)
# Processing cell (2, 1)
# Processing cell (2, 2)
# Processing cell (2, 3)
# Processing cell (2, 4)
# Processing cell (2, 5)
# Processing cell (2, 6)
# Revised: [6] removed from (5, 6)'s domain due to (2, 6)
# Revised: [6] removed from (8, 6)'s domain due to (2, 6)
# Processing cell (2, 7)
# Processing cell (2, 8)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Revised: [8] removed from (5, 6)'s domain due to (3, 6)
# Revised: [8] removed from (8, 6)'s domain due to (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Revised: [4] removed from (5, 6)'s domain due to (4, 6)
# Revised: [4] removed from (8, 6)'s domain due to (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Revised: [1] removed from (5, 6)'s domain due to (5, 2)
# Processing cell (5, 3)
# Revised: [3] removed from (5, 6)'s domain due to (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Revised: [5] removed from (5, 6)'s domain due to (5, 5)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Revised: [1] removed from (8, 6)'s domain due to (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Revised: [3] removed from (8, 6)'s domain due to (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Revised: [9] removed from (8, 6)'s domain due to (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 7)
# Processing cell (8, 8)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (5, 6)
# Processing cell (5, 6)
# Processing cell (5, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Forward checking successful
# MRV is (5, 6)
# Attempting to fill cell (5, 6) with domain values: [9]
# Trying value 9 for cell (5, 6)
# Applying forward checking
# Processing cell (0, 0)
# Processing cell (0, 1)
# Processing cell (0, 2)
# Processing cell (0, 3)
# Processing cell (0, 4)
# Processing cell (0, 5)
# Processing cell (0, 6)
# Revised: [2] removed from (8, 6)'s domain due to (0, 6)
# Processing cell (0, 7)
# Processing cell (0, 8)
# Processing cell (1, 0)
# Processing cell (1, 1)
# Processing cell (1, 2)
# Processing cell (1, 3)
# Processing cell (1, 4)
# Processing cell (1, 5)
# Processing cell (1, 6)
# Revised: [7] removed from (8, 6)'s domain due to (1, 6)
# Processing cell (1, 7)
# Processing cell (1, 8)
# Processing cell (2, 0)
# Processing cell (2, 1)
# Processing cell (2, 2)
# Processing cell (2, 3)
# Processing cell (2, 4)
# Processing cell (2, 5)
# Processing cell (2, 6)
# Revised: [6] removed from (8, 6)'s domain due to (2, 6)
# Processing cell (2, 7)
# Processing cell (2, 8)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Revised: [8] removed from (8, 6)'s domain due to (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Revised: [4] removed from (8, 6)'s domain due to (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Processing cell (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Processing cell (5, 6)
# Revised: [9] removed from (8, 6)'s domain due to (5, 6)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Revised: [1] removed from (8, 6)'s domain due to (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Revised: [3] removed from (8, 6)'s domain due to (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 7)
# Processing cell (8, 8)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Processing cell (8, 6)
# Forward checking successful
# MRV is (8, 6)
# Attempting to fill cell (8, 6) with domain values: [5]
# Trying value 5 for cell (8, 6)
# Applying forward checking
# Processing cell (0, 0)
# Processing cell (0, 1)
# Processing cell (0, 2)
# Processing cell (0, 3)
# Processing cell (0, 4)
# Processing cell (0, 5)
# Processing cell (0, 6)
# Processing cell (0, 7)
# Processing cell (0, 8)
# Processing cell (1, 0)
# Processing cell (1, 1)
# Processing cell (1, 2)
# Processing cell (1, 3)
# Processing cell (1, 4)
# Processing cell (1, 5)
# Processing cell (1, 6)
# Processing cell (1, 7)
# Processing cell (1, 8)
# Processing cell (2, 0)
# Processing cell (2, 1)
# Processing cell (2, 2)
# Processing cell (2, 3)
# Processing cell (2, 4)
# Processing cell (2, 5)
# Processing cell (2, 6)
# Processing cell (2, 7)
# Processing cell (2, 8)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Processing cell (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Processing cell (5, 6)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 6)
# Processing cell (8, 7)
# Processing cell (8, 8)
# Forward checking successful
# MRV is None
# Processing cell (0, 0)
# Processing cell (0, 1)
# Processing cell (0, 2)
# Processing cell (0, 3)
# Processing cell (0, 4)
# Processing cell (0, 5)
# Processing cell (0, 6)
# Processing cell (0, 7)
# Processing cell (0, 8)
# Processing cell (1, 0)
# Processing cell (1, 1)
# Processing cell (1, 2)
# Processing cell (1, 3)
# Processing cell (1, 4)
# Processing cell (1, 5)
# Processing cell (1, 6)
# Processing cell (1, 7)
# Processing cell (1, 8)
# Processing cell (2, 0)
# Processing cell (2, 1)
# Processing cell (2, 2)
# Processing cell (2, 3)
# Processing cell (2, 4)
# Processing cell (2, 5)
# Processing cell (2, 6)
# Processing cell (2, 7)
# Processing cell (2, 8)
# Processing cell (3, 0)
# Processing cell (3, 1)
# Processing cell (3, 2)
# Processing cell (3, 3)
# Processing cell (3, 4)
# Processing cell (3, 5)
# Processing cell (3, 6)
# Processing cell (3, 7)
# Processing cell (3, 8)
# Processing cell (4, 0)
# Processing cell (4, 1)
# Processing cell (4, 2)
# Processing cell (4, 3)
# Processing cell (4, 4)
# Processing cell (4, 5)
# Processing cell (4, 6)
# Processing cell (4, 7)
# Processing cell (4, 8)
# Processing cell (5, 0)
# Processing cell (5, 1)
# Processing cell (5, 2)
# Processing cell (5, 3)
# Processing cell (5, 4)
# Processing cell (5, 5)
# Processing cell (5, 6)
# Processing cell (5, 7)
# Processing cell (5, 8)
# Processing cell (6, 0)
# Processing cell (6, 1)
# Processing cell (6, 2)
# Processing cell (6, 3)
# Processing cell (6, 4)
# Processing cell (6, 5)
# Processing cell (6, 6)
# Processing cell (6, 7)
# Processing cell (6, 8)
# Processing cell (7, 0)
# Processing cell (7, 1)
# Processing cell (7, 2)
# Processing cell (7, 3)
# Processing cell (7, 4)
# Processing cell (7, 5)
# Processing cell (7, 6)
# Processing cell (7, 7)
# Processing cell (7, 8)
# Processing cell (8, 0)
# Processing cell (8, 1)
# Processing cell (8, 2)
# Processing cell (8, 3)
# Processing cell (8, 4)
# Processing cell (8, 5)
# Processing cell (8, 6)
# Processing cell (8, 7)
# Processing cell (8, 8)
# [[7, 6, 4, 5, 3, 8, 2, 1, 9], [5, 9, 8, 1, 6, 2, 7, 3, 4], [1, 3, 2, 4, 7, 9, 6, 8, 5], [3, 4, 9, 7, 2, 6, 8, 5, 1], [2, 5, 6, 8, 9, 1, 4, 7, 3], [8, 7, 1, 3, 4, 5, 9, 2, 6], [6, 8, 3, 2, 5, 4, 1, 9, 7], [9, 1, 5, 6, 8, 7, 3, 4, 2], [4, 2, 7, 9, 1, 3, 5, 6, 8]]
